# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import statsmodels.api as sm
import os

plt.rcParams['figure.figsize'] = (10,5)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)

print('nb ready')
# Out:
# nb ready

# %%
# Paths
trades_path = 'historical_data.csv'
sentiment_path = 'fear_greed_index.csv'

if not os.path.exists(trades_path):
    raise FileNotFoundError(f"Trades file not found: {trades_path}")
if not os.path.exists(sentiment_path):
    raise FileNotFoundError(f"Sentiment file not found: {sentiment_path}")

print('Loading files...')
df_trades = pd.read_csv(trades_path)
df_sent = pd.read_csv(sentiment_path)

print('Trades shape:', df_trades.shape)
print(df_trades.head().T)
print('\nSentiment shape:', df_sent.shape)
print(df_sent.head().T)
# Out:
# Loading files...
# Trades shape: (211224, 16)
#                                                                   0  \
# Account                  0xae5eacaf9c6b9111fd53034a602c192a04e082ed
# Coin                                                           @107
# Execution Price                                              7.9769
# Size Tokens                                                  986.87
# Size USD                                                    7872.16
# Side                                                            BUY
# Timestamp IST                                      02-12-2024 22:50
# Start Position                                                  0.0
# Direction                                                       Buy
# Closed PnL                                                      0.0
# Transaction Hash  0xec09451986a1874e3a980418412fcd0201f500c95bac...
# Order ID                                                52017706630
# Crossed                                                        True
# Fee                                                        0.345404
# Trade ID                                          895000000000000.0
# Timestamp                                           1730000000000.0
#
#                                                                   1  \
# Account                  0xae5eacaf9c6b9111fd53034a602c192a04e082ed
# Coin                                                           @107
# Execution Price                                                7.98
# Size Tokens                                                    16.0
# Size USD                                                     127.68
# Side                                                            BUY
# Timestamp IST                                      02-12-2024 22:50
# Start Position                                           986.524596
# Direction                                                       Buy
# Closed PnL                                                      0.0
# Transaction Hash  0xec09451986a1874e3a980418412fcd0201f500c95bac...
# Order ID                                                52017706630
# Crossed                                                        True
# Fee                                                          0.0056
# Trade ID                                          443000000000000.0
# Timestamp                                           1730000000000.0
#
#                                                                   2  \
# Account                  0xae5eacaf9c6b9111fd53034a602c192a04e082ed
# Coin                                                           @107
# Execution Price                                              7.9855
# Size Tokens                                                  144.09
# Size USD                                                    1150.63
# Side                                                            BUY
# Timestamp IST                                      02-12-2024 22:50
# Start Position                                          1002.518996
# Direction                                                       Buy
# Closed PnL                                                      0.0
# Transaction Hash  0xec09451986a1874e3a980418412fcd0201f500c95bac...
# Order ID                                                52017706630
# Crossed                                                        True
# Fee                                                        0.050431
# Trade ID                                          660000000000000.0
# Timestamp                                           1730000000000.0
#
#                                                                   3  \
# Account                  0xae5eacaf9c6b9111fd53034a602c192a04e082ed
# Coin                                                           @107
# Execution Price                                              7.9874
# Size Tokens                                                  142.98
# Size USD                                                    1142.04
# Side                                                            BUY
# Timestamp IST                                      02-12-2024 22:50
# Start Position                                          1146.558564
# Direction                                                       Buy
# Closed PnL                                                      0.0
# Transaction Hash  0xec09451986a1874e3a980418412fcd0201f500c95bac...
# Order ID                                                52017706630
# Crossed                                                        True
# Fee                                                        0.050043
# Trade ID                                         1080000000000000.0
# Timestamp                                           1730000000000.0
#
#                                                                   4
# Account                  0xae5eacaf9c6b9111fd53034a602c192a04e082ed
# Coin                                                           @107
# Execution Price                                              7.9894
# Size Tokens                                                    8.73
# Size USD                                                      69.75
# Side                                                            BUY
# Timestamp IST                                      02-12-2024 22:50
# Start Position                                          1289.488521
# Direction                                                       Buy
# Closed PnL                                                      0.0
# Transaction Hash  0xec09451986a1874e3a980418412fcd0201f500c95bac...
# Order ID                                                52017706630
# Crossed                                                        True
# Fee                                                        0.003055
# Trade ID                                         1050000000000000.0
# Timestamp                                           1730000000000.0
#
# Sentiment shape: (2644, 4)
#                          0             1           2             3  \
# timestamp       1517463000    1517549400  1517635800    1517722200
# value                   30            15          40            24
# classification        Fear  Extreme Fear        Fear  Extreme Fear
# date            2018-02-01    2018-02-02  2018-02-03    2018-02-04
#
#                            4
# timestamp         1517808600
# value                     11
# classification  Extreme Fear
# date              2018-02-05

# %% [markdown]
# ## Mapping

# %%
trader_id_col = 'Account'
timestamp_col = 'Timestamp IST'
entry_col = 'Execution Price'
exit_col = 'Execution Price'
size_col = 'Size Tokens'
direction_col = 'Direction'
pnl_col = 'Closed PnL'

sent_date_col = 'date'
sent_value_col = 'value'

print('Mapping ready')
# Out:
# Mapping ready

# %% [markdown]
# ##  finding for duplicates, null, missing values or any conversion required

# %%
# Trades
print(df_trades.dtypes)
print('\nMissing in trades:')
print(df_trades.isna().sum())

# Sentiment
print('\nSentiment dtypes:')
print(df_sent.dtypes)
print('\nMissing in sentiment:')
print(df_sent.isna().sum())


try:
    df_trades[timestamp_col] = pd.to_datetime(df_trades[timestamp_col], format='%d-%m-%Y %H:%M', errors='coerce')
except Exception as e:
    print('timestamp conversion error:', e)

try:
    df_sent[sent_date_col] = pd.to_datetime(df_sent[sent_date_col], errors='coerce')
except Exception as e:
    print('sentiment date conversion error:', e)


if timestamp_col in df_trades.columns:
    df_trades['date'] = df_trades[timestamp_col].dt.date
    df_trades['date'] = pd.to_datetime(df_trades['date'])
else:
    print('No timestamp column found; ensure mapping is correct')

print('\nAfter conversions:')
print(df_trades[[timestamp_col if timestamp_col in df_trades.columns else df_trades.columns[0],'date']].head())
print(df_sent[[sent_date_col, sent_value_col]].head())
# Out:
# Account              object
# Coin                 object
# Execution Price     float64
# Size Tokens         float64
# Size USD            float64
# Side                 object
# Timestamp IST        object
# Start Position      float64
# Direction            object
# Closed PnL          float64
# Transaction Hash     object
# Order ID              int64
# Crossed                bool
# Fee                 float64
# Trade ID            float64
# Timestamp           float64
# dtype: object
#
# Missing in trades:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# dtype: int64
#
# Sentiment dtypes:
# timestamp                  int64
# value                      int64
# classification            object
# date              datetime64[ns]
# dtype: object
#
# Missing in sentiment:
# timestamp         0
# value             0
# classification    0
# date              0
# dtype: int64
#
# After conversions:
#         Timestamp IST       date
# 0 2024-12-02 22:50:00 2024-12-02
# 1 2024-12-02 22:50:00 2024-12-02
# 2 2024-12-02 22:50:00 2024-12-02
# 3 2024-12-02 22:50:00 2024-12-02
# 4 2024-12-02 22:50:00 2024-12-02
#         date  value
# 0 2018-02-01     30
# 1 2018-02-02     15
# 2 2018-02-03     40
# 3 2018-02-04     24
# 4 2018-02-05     11

# %% [markdown]
#  ## Compute PnL if not present

# %%
if pnl_col in df_trades.columns and df_trades[pnl_col].notna().any():
    print('Using existing pnl column')
    df_trades['pnl'] = df_trades[pnl_col]
else:

    if all(c in df_trades.columns for c in [entry_col, exit_col, size_col]):
        print('Computing pnl from entry/exit/size/direction (if direction not present, assumes long)')
        if direction_col not in df_trades.columns:
            df_trades[direction_col] = 1
        df_trades['pnl'] = (df_trades[exit_col] - df_trades[entry_col]) * df_trades[size_col] * df_trades[direction_col]
    else:
        print('Cannot compute pnl: missing required columns. Please provide a pnl column or relevant names in the mapping cell.')

print('pnls example:')
print(df_trades[['date','pnl']].head())

# Drop rows with no date or no pnl
df_trades = df_trades.dropna(subset=['date','pnl'])
print('After dropping missing date/pnl:', df_trades.shape)
# Out:
# Using existing pnl column
# pnls example:
#         date  pnl
# 0 2024-12-02  0.0
# 1 2024-12-02  0.0
# 2 2024-12-02  0.0
# 3 2024-12-02  0.0
# 4 2024-12-02  0.0
# After dropping missing date/pnl: (211224, 18)

# %% [markdown]
# ## Aggregate per-trader daily metrics

# %%
agg = df_trades.groupby([trader_id_col,'date']).agg(
    trades_count = ('pnl','count'),
    total_pnl = ('pnl','sum'),
    avg_pnl = ('pnl','mean'),
    win_rate = ('pnl', lambda x: (x>0).mean()),
    std_pnl = ('pnl','std')
).reset_index()


agg['std_pnl'] = agg['std_pnl'].fillna(0)


agg = agg.sort_values([trader_id_col,'date'])
agg['rolling_pnl_7d'] = agg.groupby(trader_id_col)['total_pnl'].transform(lambda x: x.rolling(7, min_periods=1).mean())

print('Aggregated sample:')
print(agg.head())
print('\nAgg shape:', agg.shape)
# Out:
# Aggregated sample:
#                                       Account       date  trades_count  \
# 0  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-11           177
# 1  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-17            68
# 2  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-18            40
# 3  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-22            12
# 4  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-26            27
#
#    total_pnl      avg_pnl  win_rate      std_pnl  rolling_pnl_7d
# 0        0.0     0.000000  0.000000     0.000000            0.00
# 1        0.0     0.000000  0.000000     0.000000            0.00
# 2        0.0     0.000000  0.000000     0.000000            0.00
# 3   -21227.0 -1768.916667  0.000000  1526.178379        -5306.75
# 4     1603.1    59.374074  0.444444   172.316814        -3924.78
#
# Agg shape: (2341, 8)

# %% [markdown]
# ## Prepare sentiment series

# %%
if sent_date_col in df_sent.columns:
    df_sent['date'] = pd.to_datetime(df_sent[sent_date_col]).dt.date
    df_sent['date'] = pd.to_datetime(df_sent['date'])
else:
    raise KeyError('Sentiment date column not found. Update mapping.')


if sent_value_col in df_sent.columns:
    df_sent = df_sent.rename(columns={sent_value_col:'fear_greed_value'})
else:
    raise KeyError('Sentiment score column not found. Update mapping.')

sent_daily = df_sent.groupby('date')['fear_greed_value'].mean().reset_index().sort_values('date')

date_idx = pd.date_range(sent_daily['date'].min(), sent_daily['date'].max())
sent_daily = sent_daily.set_index('date').reindex(date_idx).rename_axis('date').reset_index()
sent_daily['fear_greed_value'] = sent_daily['fear_greed_value'].ffill()

print('Sentiment sample:')
print(sent_daily.head())
print('\nSentiment range:', sent_daily['fear_greed_value'].min(), 'to', sent_daily['fear_greed_value'].max())
# Out:
# Sentiment sample:
#         date  fear_greed_value
# 0 2018-02-01              30.0
# 1 2018-02-02              15.0
# 2 2018-02-03              40.0
# 3 2018-02-04              24.0
# 4 2018-02-05              11.0
#
# Sentiment range: 5.0 to 95.0

# %% [markdown]
# ## Merging

# %%
agg = agg.merge(sent_daily, how='left', on='date')
agg = agg.sort_values([trader_id_col,'date'])

print('Merged sample:')
print(agg.head())
# Out:
# Merged sample:
#                                       Account       date  trades_count  \
# 0  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-11           177
# 1  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-17            68
# 2  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-18            40
# 3  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-22            12
# 4  0x083384f897ee0f19899168e3b1bec365f52a9012 2024-11-26            27
#
#    total_pnl      avg_pnl  win_rate      std_pnl  rolling_pnl_7d  \
# 0        0.0     0.000000  0.000000     0.000000            0.00
# 1        0.0     0.000000  0.000000     0.000000            0.00
# 2        0.0     0.000000  0.000000     0.000000            0.00
# 3   -21227.0 -1768.916667  0.000000  1526.178379        -5306.75
# 4     1603.1    59.374074  0.444444   172.316814        -3924.78
#
#    fear_greed_value_x  fear_greed_value_y
# 0                76.0                76.0
# 1                90.0                90.0
# 2                83.0                83.0
# 3                94.0                94.0
# 4                79.0                79.0

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
# 1) Sentiment over time
fig, x = plt.subplots()
x.plot(sent_daily['date'], sent_daily['fear_greed_value'], color = 'red')
x.set_title(' Bitcoin Market Sentiment over time')
x.set_xlabel('Date')
x.set_ylabel(' Bitcoin Market ')
x.xaxis.set_major_formatter(DateFormatter('%Y-%m'))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2) Distribution of daily total_pnl
fig, x = plt.subplots()
x.hist(agg['total_pnl'].dropna(), bins=80, color='magenta')
x.set_title('Distribution of daily total PnL (per trader-day)')
plt.show()

# 3) Boxplot of total_pnl by sentiment quartile
agg['sent_q'] = pd.qcut(agg['fear_greed_value_x'], q=4, labels=False, duplicates='drop')
fig, ax = plt.subplots()
agg.boxplot(column='total_pnl', by='sent_q', ax=ax, color='yellow')
ax.set_title('Total PnL by sentiment quartile')
plt.suptitle('')
plt.show()

# 4) Scatter sentiment vs total_pnl (sample)
sample = agg.sample(min(2000, len(agg)), random_state=42)
fig, ax = plt.subplots()
ax.scatter(sample['fear_greed_value_x'], sample['total_pnl'], alpha=0.6, color='teal')
ax.set_xlabel(' Bitcoin Market Sentiment')
ax.set_ylabel('Total PnL')
ax.set_title('Scatter: sentiment vs total_pnl (sample)')
plt.show()

# %% [markdown]
# ## Lag analysis

# %%
for lag in range(0,6):
    agg[f'sent_lag_{lag}'] = agg.groupby(trader_id_col)['fear_greed_value_x'].shift(lag)

corrs = {}
for lag in range(0,6):
    col = f'sent_lag_{lag}'
    valid = agg[['total_pnl', col]].dropna()
    corrs[lag] = valid['total_pnl'].corr(valid[col]) if len(valid)>0 else np.nan

print('Correlation of total_pnl with sentiment lags (0..5):')
print(corrs)

# Plot correlations
fig, ax = plt.subplots()
ax.plot(list(corrs.keys()), list(corrs.values()), marker='D', color ='green', ls='-.')
ax.set_xlabel('Lag (days)')
ax.set_ylabel('Pearson correlation')
ax.set_title('Total_pnl vs sentiment ')
plt.show()
# Out:
# Correlation of total_pnl with sentiment lags (0..5):
# {0: np.float64(0.0006552234574174165), 1: np.float64(-0.008697215078537487), 2: np.float64(-0.009023459403292496), 3: np.float64(-0.005708497009535124), 4: np.float64(0.005986634563894434), 5: np.float64(0.0020708986730119845)}

# %% [markdown]
# ## Clustering traders by behavior

# %%
trader_feats = agg.groupby(trader_id_col).agg(
    mean_daily_pnl = ('total_pnl','mean'),
    median_daily_pnl = ('total_pnl','median'),
    win_rate = ('win_rate','mean'),
    avg_trades_day = ('trades_count','mean'),
    pnl_vol = ('std_pnl','mean')
).dropna()

print('Trader features sample:')
print(trader_feats.head())

scaler = StandardScaler()
X = scaler.fit_transform(trader_feats)

# Choose k
k = 4
km = KMeans(n_clusters=k, random_state=42)
labels = km.fit_predict(X)
trader_feats['cluster'] = labels

# PCA 2D for visualization
pca = PCA(n_components=2)
coords = pca.fit_transform(X)
trader_feats['pc1'] = coords[:,0]
trader_feats['pc2'] = coords[:,1]

fig, ax = plt.subplots()
for cl in sorted(trader_feats['cluster'].unique()):
    sub = trader_feats[trader_feats['cluster']==cl]
    ax.scatter(sub['pc1'], sub['pc2'], label=f'cluster {cl}', alpha=0.6, )
ax.legend()
ax.set_title('Trader clusters ')
plt.show()

print('\nCluster sizes:')
print(trader_feats['cluster'].value_counts())
# Out:
# Trader features sample:
#                                             mean_daily_pnl  median_daily_pnl  \
# Account
# 0x083384f897ee0f19899168e3b1bec365f52a9012    66676.242499      35548.544350
# 0x23e7a7f8d14b550961925fbfdaa92f5d195ba5bd      920.871548        686.342345
# 0x271b280974205ca63b716753467d5a371de622ab    -5869.682610       2111.177671
# 0x28736f43f1e871e6aa8b1148d38d4994275d72c4      817.684040        214.195142
# 0x2c229d22b100a7beb69122eed721cee9b24011dd     2444.318913        276.768700
#
#                                             win_rate  avg_trades_day  \
# Account
# 0x083384f897ee0f19899168e3b1bec365f52a9012  0.352333      159.083333
# 0x23e7a7f8d14b550961925fbfdaa92f5d195ba5bd  0.397134      140.000000
# 0x271b280974205ca63b716753467d5a371de622ab  0.379952      317.416667
# 0x28736f43f1e871e6aa8b1148d38d4994275d72c4  0.452509       82.166667
# 0x2c229d22b100a7beb69122eed721cee9b24011dd  0.498708       46.942029
#
#                                                 pnl_vol
# Account
# 0x083384f897ee0f19899168e3b1bec365f52a9012  4938.034175
# 0x23e7a7f8d14b550961925fbfdaa92f5d195ba5bd    91.474790
# 0x271b280974205ca63b716753467d5a371de622ab   188.439838
# 0x28736f43f1e871e6aa8b1148d38d4994275d72c4    38.996391
# 0x2c229d22b100a7beb69122eed721cee9b24011dd   112.139426
# Cluster sizes:
# cluster
# 1    18
# 0    12
# 2     1
# 3     1
# Name: count, dtype: int64

# %% [markdown]
# ## Simple regression

# %%
reg_df = agg.dropna(subset=['total_pnl','fear_greed_value_x'])
reg_df = reg_df.sample(min(len(reg_df), 20000), random_state=42)

X = reg_df[['fear_greed_value_x','trades_count','rolling_pnl_7d']].fillna(0)
X = sm.add_constant(X)
y = reg_df['total_pnl']
model = sm.OLS(y, X).fit(cov_type='HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              total_pnl   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     12.69
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           3.17e-08
# Time:                        19:49:40   Log-Likelihood:                -26830.
# No. Observations:                2341   AIC:                         5.367e+04
# Df Residuals:                    2337   BIC:                         5.369e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -2487.5198   1598.983     -1.556      0.120   -5621.468     646.428
# fear_greed_value_x    24.2997     25.067      0.969      0.332     -24.831      73.431
# trades_count           9.5716      7.318      1.308      0.191      -4.772      23.915
# rolling_pnl_7d         1.0951      0.190      5.751      0.000       0.722       1.468
# ==============================================================================
# Omnibus:                     2132.345   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           743480.175
# Skew:                           3.463   Prob(JB):                         0.00
# Kurtosis:                      90.030   Cond. No.                     4.49e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 4.49e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Save aggregated data and trader features for later use

# %%
if not os.path.exists('/mnt/data'):
    os.makedirs('/mnt/data')

agg.to_csv('agg_trader_daily.csv', index=False)
trader_feats.to_csv('trader_features_clusters.csv')

print('Saved: agg_trader_daily.csv and trader_features_clusters.csv')
# Out:
# Saved: agg_trader_daily.csv and trader_features_clusters.csv
